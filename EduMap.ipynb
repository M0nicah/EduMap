# %%
import pandas as pd

# %%
kenya=pd.read_csv("C:\\Users\\user\\Desktop\\kenya_primary_schools_edumap_ready.csv")

# %%
kenya.head()
# Out:
#      FID          Name_of_Sc          Level_  Status              SchSponsor  \
# 0  10001      CHEBIREBEI PRI  PRIMARY SCHOOL  PUBLIC  RELIGIOUS ORGANIZATION
# 1  10002         WASEGES PRI  PRIMARY SCHOOL  PUBLIC  RELIGIOUS ORGANIZATION
# 2  10003         KIRIBOT PRI  PRIMARY SCHOOL  PUBLIC               COMMUNITY
# 3  10004     KABUSWO PRI SCH  PRIMARY SCHOOL  PUBLIC               COMMUNITY
# 4  10005  VONDENI PRI SCHOOL  PRIMARY SCHOOL  PUBLIC               COMMUNITY
#
#    Type1     Type2     Type3  PupilTeach  ClassrmRat  ...  Division  Location  \
# 0  MIXED  DAY ONLY  ORDINARY        15.7         5.9  ...  KISANANA   MOGOTIO
# 1  MIXED  DAY ONLY  ORDINARY        24.5        18.4  ...  KISANANA   MOGOTIO
# 2  MIXED  DAY ONLY  ORDINARY        23.6        14.8  ...  KISANANA   MOGOTIO
# 3  MIXED  DAY ONLY  ORDINARY        33.3        29.6  ...  KISANANA   MOGOTIO
# 4  MIXED  DAY ONLY  ORDINARY        31.8        23.1  ...   MASINGA     KIVAA
#
# ...

# %%
kenya.tail()
# Out:
#          FID       Name_of_Sc          Level_  Status              SchSponsor  \
# 31225  30996     MGANGANI PRI  PRIMARY SCHOOL  PUBLIC  CENTRAL GOVERNMENT/DEB
# 31226  30997     KISIKINI PRI  PRIMARY SCHOOL  PUBLIC  CENTRAL GOVERNMENT/DEB
# 31227  30998  NGOMANO PRI SCH  PRIMARY SCHOOL  PUBLIC  CENTRAL GOVERNMENT/DEB
# 31228  30999      NGILUNI PRI  PRIMARY SCHOOL  PUBLIC  CENTRAL GOVERNMENT/DEB
# 31229  31000   KIKASO PRI SCH  PRIMARY SCHOOL  PUBLIC  CENTRAL GOVERNMENT/DEB
#
#        Type1     Type2     Type3  PupilTeach  ClassrmRat  ...  Division  \
# 31225  MIXED  DAY ONLY  ORDINARY        40.8        40.8  ...    YATHUI
# 31226  MIXED  DAY ONLY  ORDINARY        10.0         7.5  ...   CHULUNI
# 31227  MIXED  DAY ONLY  ORDINARY        18.0        13.5  ...    YATHUI
# 31228  MIXED  DAY ONLY  ORDINARY        45.7        34.3  ...   CHULUNI
# 31229  MIXED  DAY ONLY  ORDINARY        39.5        34.3  ...    YATHUI
#
# ...

# %%
kenya_fixed=kenya.drop('PupilTeach',axis=1)

# %%
kenya_fixed_a=kenya_fixed.drop('ToiletRatio',axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 kenya_fixed_a=kenya_fixed.drop('ToiletRatio',axis=1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# ...

# %%
kenya_fixed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31230 entries, 0 to 31229
# Data columns (total 40 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   FID                       31230 non-null  int64
#  1   Name_of_Sc                31229 non-null  object
#  2   Level_                    31229 non-null  object
#  3   Status                    31229 non-null  object
#  4   SchSponsor                31229 non-null  object
#  5   Type1                     31229 non-null  object
#  6   Type2                     31229 non-null  object
#  7   Type3                     31229 non-null  object
#  8   ClassrmRat                31229 non-null  float64
#  9   ToiletRati                31229 non-null  float64
#  10  No_Classrm                31229 non-null  float64
#  11  BoysToilet                31229 non-null  float64
#  12  GirlsToilet               31229 non-null  float64
# ...

# %%
kenya=pd.read_csv("C:\\Users\\user\\Desktop\\EduMap_kenya_students_cleaned.csv")

# %%
kenya.head()
# Out:
#      FID          Name_of_Sc          Level_  Status              SchSponsor  \
# 0  10001      CHEBIREBEI PRI  PRIMARY SCHOOL  PUBLIC  RELIGIOUS ORGANIZATION
# 1  10002         WASEGES PRI  PRIMARY SCHOOL  PUBLIC  RELIGIOUS ORGANIZATION
# 2  10003         KIRIBOT PRI  PRIMARY SCHOOL  PUBLIC               COMMUNITY
# 3  10004     KABUSWO PRI SCH  PRIMARY SCHOOL  PUBLIC               COMMUNITY
# 4  10005  VONDENI PRI SCHOOL  PRIMARY SCHOOL  PUBLIC               COMMUNITY
#
#    Type1     Type2     Type3  PupilTeach     Province  District  Division  \
# 0  MIXED  DAY ONLY  ORDINARY        15.7  RIFT VALLEY  KOIBATEK  KISANANA
# 1  MIXED  DAY ONLY  ORDINARY        24.5  RIFT VALLEY  KOIBATEK  KISANANA
# 2  MIXED  DAY ONLY  ORDINARY        23.6  RIFT VALLEY  KOIBATEK  KISANANA
# 3  MIXED  DAY ONLY  ORDINARY        33.3  RIFT VALLEY  KOIBATEK  KISANANA
# 4  MIXED  DAY ONLY  ORDINARY        31.8      EASTERN  MACHAKOS   MASINGA
#
# ...

# %%
kenya.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31230 entries, 0 to 31229
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   FID                       31230 non-null  int64
#  1   Name_of_Sc                31229 non-null  object
#  2   Level_                    31229 non-null  object
#  3   Status                    31229 non-null  object
#  4   SchSponsor                31229 non-null  object
#  5   Type1                     31229 non-null  object
#  6   Type2                     31229 non-null  object
#  7   Type3                     31229 non-null  object
#  8   PupilTeach                31229 non-null  float64
#  9   Province                  31229 non-null  object
#  10  District                  31229 non-null  object
#  11  Division                  31229 non-null  object
#  12  Location                  31229 non-null  object
# ...

# %%
kenya.Type2.value_counts()
# Out:
# Type2
# DAY ONLY                 28572
# DAY & BOARDING            1660
# BOARDING ONLY              544
#                            405
# DAY AND BOARDING            40
# DAY AND BOARDING ONLY        3
# N                            1
# I                            1
# DE                           1
# DAY& BOARDING                1
# DAY 7& BOARDING              1
# Name: count, dtype: int64

# %%
kenya_a=kenya.drop('PupilTeach',axis=1)

# %%
kenya_a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31230 entries, 0 to 31229
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   FID                       31230 non-null  int64
#  1   Name_of_Sc                31229 non-null  object
#  2   Level_                    31229 non-null  object
#  3   Status                    31229 non-null  object
#  4   SchSponsor                31229 non-null  object
#  5   Type1                     31229 non-null  object
#  6   Type2                     31229 non-null  object
#  7   Type3                     31229 non-null  object
#  8   Province                  31229 non-null  object
#  9   District                  31229 non-null  object
#  10  Division                  31229 non-null  object
#  11  Location                  31229 non-null  object
#  12  Costituenc                31229 non-null  object
# ...

# %%
kenya_b=kenya_a.drop('Type1',axis=1)
kenya_c=kenya_b.drop('Type2',axis=1)
kenya_d=kenya_c.drop('Type3',axis=1)

# %%
kenya_schools=kenya_d.rename(columns={'Level_':'School_type','FID':'School_ID','Constituenc':'Constituency','Total Teachers':'Total_Teachers','Total Pupils':'Total_Students','Pupils per Teacher':'Students_per_Teacher','Required Teachers (40:1)':'Teachers_Required','Extra Teachers Needed':'Extra_Teachers_Required'})

# %%
kenya_schools.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31230 entries, 0 to 31229
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   School_ID                31230 non-null  int64
#  1   Name_of_Sc               31229 non-null  object
#  2   School_type              31229 non-null  object
#  3   Status                   31229 non-null  object
#  4   SchSponsor               31229 non-null  object
#  5   Province                 31229 non-null  object
#  6   District                 31229 non-null  object
#  7   Division                 31229 non-null  object
#  8   Location                 31229 non-null  object
#  9   Costituenc               31229 non-null  object
#  10  Total_Teachers           31230 non-null  int64
#  11  Total_Students           31230 non-null  int64
#  12  Students_per_Teacher     31230 non-null  float64
#  13  Teachers_Required        31230 non-null  float64
# ...

# %%
kenya_schools.Status.value_counts()
# Out:
# Status
# PUBLIC     23792
# PRIVATE     7437
# Name: count, dtype: int64

# %%
kenya_schools.to_csv("C:\\Users\\user\\Desktop\\EduMap_kenyan.csv")
